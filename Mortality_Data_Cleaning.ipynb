# %%
import pandas as pd
pd.set_option("display.max_rows", 85)
pd.set_option("display.max_columns", 285)
import os
path = 'C:\\mortality_input'
os.chdir(path)
import numpy as np
from xlsxwriter.utility import xl_rowcol_to_cell

# %% [markdown]
# # Importing of Data

# %%
cell = pd.read_excel('Initial_survey_Mosque_List_-_all_versions.xlsx',sheet_name='Initial survey Mosque List')

# %%
mosque_list = pd.read_excel('Initial_survey_Mosque_List_-_all_versions.xlsx',sheet_name='Mosque_List')

# %%
deaths = pd.read_excel('Initial_survey_Mosque_List_-_all_versions.xlsx',sheet_name='Rep_Deaths')

# %%
cell = cell[['starttime',
 'endtime',
 'audit',
 'audit_URL',
 'starttime.1',
 'endtime.1',
 'Mosque List',
 'GPS Point:',
 '_GPS Point:_latitude',
 '_GPS Point:_longitude',
 '_GPS Point:_precision',
 'Date and Time:',
 'Surveyor Name:',
 'Surveyor ID:',
 'Type of Visit',
 'Cell FID',
 'OID',
 "This cell's pouplation size is estimated.",
 "This cell's pouplation income level",
 'Nahia ID',
 'Nahia',
 'Province',
 'District',
 'Has a building?',
 'The number of mosques shown in the statile image in this cell',
 'Bucket',
 'Selection',
 'Comment For Industrial Area',
 'Changes Has been made in selection from start of sampling',
 'Is the cell should be visited?',
 'Centroid X of cell',
 'Centroid Y of cell',
 'If this cell located under 1 HH selection',
 'Off setting',
 'Is the Servey of this cell completed?',
 'Validation',
 'Valid By',
 '_id',
 '_uuid',
 '_submission_time',
 '_validation_status',
 '_status',
 '_submitted_by',
 '_index']]

# %%
cell4sheet =cell[[
 'Cell FID',
 'OID',
 'Nahia ID',
 'Nahia',
 'Province',
 'District',
 '_uuid']]

# %%
mosque_list = pd.merge(mosque_list, cell4sheet, left_on='_submission__uuid', right_on='_uuid', how='left')

# %%
#list(mosque_list.columns)

# %%
mosque_list = mosque_list[[ 'Cell FID',
 'OID',
 'Nahia ID',
 'Nahia',
 'Province',
 'District',
 'Mosque Name',
 'Mosque ID',
 'GPS Point:',
 '_GPS Point:_latitude',
 '_GPS Point:_longitude',
 '_GPS Point:_altitude',
 '_GPS Point:_precision',
 'Type of Mosque',
 'Is the mosque located in a residential area?',
 'Street',
 'Manteqa or PD',
 'Qaria ya Shahr',
 'Woluswali, Wolayat',
 'Complete Address',
 'Mosque Name Faris',
 'Mosque Name English',
 'village Distance',
 'Is there availability to visit in the next survey?',
 'Mullah Phone Number',
 'Mullah Second Phone Number if possible',
 'Is it possible to interview with Mullah?',
 'GPS Point:.1',
 '_GPS Point:_latitude.1',
 '_GPS Point:_longitude.1',
 '_GPS Point:_altitude.1',
 '_GPS Point:_precision.1',
 'Date and Time:',
 'Mosque name',
 'conset',
 'Name of head of mosque',
 'Membership estimate',
 'Male attendance Juma',
 'Date of interview',
 'Was there any mosque missed in nearby area',
 "${Mosque_name}: \n${Complete_Address}:  \n\nPage 3 shows the area of the mosque as a map and as a satellite image.  Use it to estimate the extent of the mosque's membership.",
 '${Mosque_name}: \n${Complete_Address}: \n\nSketch a line to show area within which the majority of people are likely to be members of this mosque. In the map which you have recived by project manager',
 '${Mosque_name}\nUpload the map with Sketch line which show members of mosque area:',
 '${Mosque_name}\nUpload the map with Sketch line which show members of mosque area:_URL',
 'Dose the mullah remember any death since mentioned period?',
 'How many people dose the mullah remember since last vist or since 22 Nov 2021?',
 'Take a selfie with the mosque in the background.  Make sure that your phone is set to capture coordinates and dates with photos.   The "Phone Settings" tab on the Google sheet explains how to.   The project will not accept reports that can not be verified with a mosque photo.',
 'Take a selfie with the mosque in the background.  Make sure that your phone is set to capture coordinates and dates with photos.   The "Phone Settings" tab on the Google sheet explains how to.   The project will not accept reports that can not be verified with a mosque photo._URL',
 'Number of Rows for Pary',
 'Number of people can sit in a row',
 '_index',
 '_parent_table_name',
 '_parent_index',
 '_submission__id',
 '_submission__uuid',
 '_submission__submission_time',
 '_submission__validation_status',
 '_submission__notes']]

# %%
mosque_list4sheet =  mosque_list[['Cell FID',
 'OID',
 'Nahia ID',
 'Nahia',
 'Province',
 'District',
 'Mosque Name',
 'Mosque ID',
 'Mosque Name Faris',
 'Mosque Name English',
 '_submission__uuid']]

# %%
deaths = pd.merge(deaths, mosque_list4sheet, left_on='_submission__uuid', right_on='_submission__uuid', how='left')

# %%
#list(deaths.columns)

# %%
deaths = deaths[['Cell FID',
 'OID',
 'Nahia ID',
 'Nahia',
 'Province',
 'District',
 'Mosque Name',
 'Mosque ID',
 'Mosque Name Faris',
 'Mosque Name English',
 'Date of death',
 'Name of the deceased',
 'Gender',
 'Age',
 "Today's date",
 "Enumerator's name",
 '_index',
 '_submission__uuid']]

# %% [markdown]
# ## Correction Long

# %%
cell.loc[cell['_uuid'] =='66f6c319-ab3f-4a23-af4b-005ce4de0417', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='69c3c693-b5ab-46d0-8ce2-f0ec0a5e891c', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='0f780179-8285-40d9-a91b-2a74b0637e3c', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='820e258d-3245-4881-a551-d5079e121150', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='e116ee48-d405-4b26-8f11-156425f5a378', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='ccf4a49c-01ad-4777-8928-3c0ed836b488', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='5e42caf9-ac04-4083-8e32-ed3ad66629df', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='bd5f1be7-a7dc-4a00-8621-7fa82f22e17a', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='b466d7cc-1660-4bf1-b81a-6d336739cc7d', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='b70e0e61-b76e-4919-aa31-616a26c29a5a', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='f8b8da2c-3e02-4013-bed4-51f4aafa6cde', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='96848dcf-3303-4c53-bcca-280dd1b7fd26', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='c7f46097-95b9-4cbe-b801-78c3fa0b5fe1', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='2eb36ce3-2729-449c-9c20-3f50cbc3f4b2', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='cf8758c3-d7af-46bb-99a4-70d9bed0d1e9', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='1d4fa4b3-cb36-4926-83f1-8645a2809975', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='15134843-52e8-41c0-86ce-2861f3a3c2ed', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='85da0d88-4945-4e7c-891c-b5708934b52d', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='b53910bb-02f5-487d-8c69-383e76458869', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='d6a3a26a-4549-4da4-9a09-3a534cd3aeeb', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='b604cd59-e1fd-40e2-81db-56a793bd8ff8', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='8cf927cb-27cf-4459-a339-d4f3483dd238', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='22147b82-aa4a-42ef-a5b4-bcfe4e64b07c', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='c4604464-4262-4a5b-8f38-814da07fa71f', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='113c852f-c15d-47b1-8928-8ac4e92ae789', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='eaea331e-6538-4f62-8317-8b8b62e0c94c', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='57e8e82d-c855-4302-81a1-c5adc7754d6b', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='3fccf6af-2a59-4497-8076-9f8e9adb1684', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =
"Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='53cb4e22-5de2-417c-8d00-bdaad059f9bb', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='f153d24b-4b07-4a41-b949-f9b18c18e527', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='242ce89e-0a77-46bd-a6d9-a885980b1579', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='d1e025cc-3fc5-4262-81dd-4cdc867f49a2', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='22678cde-558b-4b5f-8bde-cf9a6839b8a0', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='0b60465a-e440-4f24-ad80-a3fe9a38cd2b', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='376f4f83-900c-4ff6-a407-5e82188ffc2f', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='0ed6c59a-a7b1-41ed-ba4c-8f1147c4f0bc', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='d7735e21-3ed6-404d-a37b-390159f7c190', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='56e9a36d-6003-4395-bb0c-ca62d70db2ef', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='ed245366-38a5-4932-b4bd-f2cf15ced284', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='d7c47035-93c0-4baf-a1d3-b556d7f968bf', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='43420240-f623-4921-bb9f-0a1130701049', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='25374669-e71f-402c-b541-fffd085e32a7', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='70a75805-8e58-4d61-8b73-3c3f8d83e776', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='89f8d830-4313-4a9b-89c5-d63d4dd38330', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='eac82b2c-3085-41a9-95b6-5f8c0fc192e9', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='901cce4d-564b-441f-9ea8-a7fc860a145f', "Valid By"] = 'Samir'
cell.loc[cell['_uuid'] =='8a4b664a-1907-41cd-9753-21c9ea096283', "Valid By"] = 'Samir'

# %% [markdown]
# # Eporting of Data

# %%
path = 'C:\\'
os.chdir(path)
Nfolder = 'mortality_out'
try:
    if not os.path.exists(Nfolder):
        os.makedirs(Nfolder)
except os.error:
    print("Path is already exist")

# %%
path = 'C:\\mortality_out'
os.chdir(path)
Nfolder = 'OutPut'
try:
    if not os.path.exists(Nfolder):
        os.makedirs(Nfolder)
except os.error:
    print("Path is already exist")

# %%
path = 'C:\\mortality_out\\OutPut'
os.chdir(path)

# %%
writer = pd.ExcelWriter('Mortality Initial Survey.xlsx', engine="xlsxwriter")
cell.to_excel(writer, sheet_name='cell', index=False)
mosque_list.to_excel(writer, sheet_name='mosque_list', index=False)
deaths.to_excel(writer, sheet_name='deaths', index=False)

workbook = writer.book
worksheet = writer.sheets['cell']
worksheet1 = writer.sheets['mosque_list']
worksheet2 = writer.sheets['deaths']

header_format = workbook.add_format({
    "bg_color": "#DCE6F1",
    "font":"Trebuchet MS",
    "bold":True,
    "font_size":9})

for col_num, value in enumerate(cell.columns.values):
    worksheet.write(0, col_num, value, header_format)
for col_num, value in enumerate(mosque_list.columns.values):
    worksheet1.write(0, col_num, value, header_format)
for col_num, value in enumerate(deaths.columns.values):
    worksheet2.write(0, col_num, value, header_format)

coloum_format = workbook.add_format({
    "font":"Trebuchet MS",
    "font_size":9})              
worksheet.set_column('A:AH', 10, coloum_format )
worksheet1.set_column('A:J', 10, coloum_format )
worksheet2.set_column('A:W', 10, coloum_format )

writer.save()

# %%
os.startfile(path)

# %%
import watermark

# %%
# %reload_ext watermark

# %watermark -v -m -p wget,pandas,numpay,watermark

# %watermark -u -n -t -z
# Out:
# Python implementation: CPython
# Python version       : 3.9.12
# IPython version      : 8.2.0
#
# wget     : not installed
# pandas   : 1.4.2
# numpay   : not installed
# watermark: 2.3.1
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 165 Stepping 2, GenuineIntel
# CPU cores   : 12
# Architecture: 64bit
#
# Last updated: Wed Aug 17 2022 07:28:42Afghanistan Standard Time
